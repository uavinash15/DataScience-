# %% [markdown]
# <a href="https://colab.research.google.com/github/uavinash15/DataScience-/blob/main/Notebooks/Clustering/Clustering_Income_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clustering on Income Data**

# %%
import pandas as pd
customers_df=pd.read_csv('Income Data.csv')

# %%
customers_df
# Out:
#       income    age
# 0    41100.0  48.75
# 1    54100.0  28.10
# 2    47800.0  46.75
# 3    19100.0  40.25
# 4    18200.0  35.80
# ..       ...    ...
# 295  38300.0  46.10
# 296  27400.0  44.15
# 297  54200.0  28.25
# 298  41800.0  44.85
# 299  38600.0  39.35
#
# [300 rows x 2 columns]

# %%
customers_df.head()
# Out:
#     income    age
# 0  41100.0  48.75
# 1  54100.0  28.10
# 2  47800.0  46.75
# 3  19100.0  40.25
# 4  18200.0  35.80

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
sn.lmplot(x="age", y="income", data=customers_df, fit_reg=False)
plt.show()

# %% [markdown]
# # Finding Similarities Using Distances

# %% [markdown]
# *Euclidean Distance*

# %% [markdown]
# *Other Distance Metrics*

# %% [markdown]
# # **K-MEANS CLUSTERING**

# %%
from sklearn.cluster import KMeans
clusters=KMeans(3)
clusters.fit(customers_df)
# Out:
# KMeans(n_clusters=3)

# %%
clusters.labels_
# Out:
# array([0, 2, 0, 1, 1, 1, 2, 0, 1, 0, 2, 2, 2, 0, 2, 1, 0, 0, 1, 2, 1, 0,
#        2, 0, 1, 1, 0, 1, 2, 2, 1, 0, 0, 2, 2, 1, 2, 1, 0, 2, 1, 2, 0, 2,
#        2, 1, 2, 1, 1, 2, 1, 2, 1, 1, 2, 0, 0, 1, 1, 2, 2, 2, 0, 1, 2, 1,
#        0, 2, 0, 2, 1, 1, 1, 1, 2, 0, 2, 1, 0, 0, 1, 0, 2, 0, 0, 2, 2, 1,
#        0, 0, 1, 2, 1, 2, 2, 2, 0, 2, 1, 0, 2, 1, 0, 2, 2, 0, 1, 0, 2, 2,
#        0, 1, 2, 0, 1, 1, 0, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 1, 1, 1,
#        0, 1, 1, 2, 1, 0, 1, 1, 2, 0, 2, 0, 1, 1, 0, 1, 1, 2, 0, 1, 0, 2,
#        1, 1, 2, 2, 0, 2, 0, 2, 2, 0, 1, 2, 0, 0, 0, 1, 2, 0, 1, 2, 2, 2,
#        0, 2, 0, 2, 2, 1, 0, 0, 0, 0, 2, 1, 0, 1, 0, 0, 2, 2, 1, 0, 2, 1,
#        0, 1, 2, 1, 2, 1, 2, 1, 0, 1, 0, 2, 0, 0, 1, 2, 2, 2, 2, 0, 1, 2,
#        0, 2, 2, 2, 0, 1, 1, 0, 2, 0, 0, 2, 2, 0, 2, 1, 1, 1, 0, 0, 2, 1,
#        1, 1, 1, 2, 0, 1, 0, 2, 2, 0, 2, 2, 1, 0, 2, 1, 0, 2, 1, 2, 1, 1,
#        0, 1, 0, 2, 2, 2, 2, 0, 0, 0, 0, 2, 1, 1, 2, 2, 0, 2, 2, 2, 1, 2,
# ...

# %%
customers_df["clusterid"]=clusters.labels_

# %%
customers_df.head()
# Out:
#     income    age  clusterid
# 0  41100.0  48.75          0
# 1  54100.0  28.10          2
# 2  47800.0  46.75          0
# 3  19100.0  40.25          1
# 4  18200.0  35.80          1

# %% [markdown]
# # Plotting Customers with Their Segments

# %%
markers=['+','^','.']
sn.lmplot(x="age",y="income",data=customers_df,hue="clusterid",fit_reg=False,markers=markers)  #lmplot=linearmodel plot
plt.show()

# %%
customers_df.max()
# Out:
# income       60200.0
# age             50.4
# clusterid        2.0
# dtype: float64

# %% [markdown]
# **Normalizing Features**

# %%
from sklearn.preprocessing import StandardScaler

# %%
sclaer=StandardScaler()
scaled_customers_df=sclaer.fit_transform(customers_df[["age","income"]])
scaled_customers_df[0:5]
# Out:
# array([[ 1.3701637 ,  0.09718548],
#        [-1.3791283 ,  0.90602749],
#        [ 1.10388844,  0.51405021],
#        [ 0.23849387, -1.27162408],
#        [-0.35396857, -1.32762083]])

# %%
from sklearn.cluster import KMeans
clusters_new=KMeans(3,random_state=42)
clusters_new.fit(scaled_customer_df)
customers_df["clusterid_new"]=clusters_new.labels_
#print(clusters_new.labels_)
customers_df
# Out:
#       income    age  clusterid  clusterid_new
# 0    41100.0  48.75          0              0
# 1    54100.0  28.10          2              1
# 2    47800.0  46.75          0              0
# 3    19100.0  40.25          1              2
# 4    18200.0  35.80          1              2
# ..       ...    ...        ...            ...
# 295  38300.0  46.10          0              0
# 296  27400.0  44.15          1              2
# 297  54200.0  28.25          2              1
# 298  41800.0  44.85          0              0
# 299  38600.0  39.35          0              0
#
# [300 rows x 4 columns]

# %%
markers=['+','^','.']

# %%
sn.lmplot(x="age",y="income",data=customers_df,hue="clusterid_new",fit_reg=False,markers=markers)
plt.show()

# %%
clusters.cluster_centers_
# Out:
# array([[4.30539326e+04, 4.64191011e+01],
#        [1.81447917e+04, 3.91744792e+01],
#        [5.46756522e+04, 3.17004348e+01]])

# %%
clusters_new.cluster_centers_
# Out:
# array([[ 1.08753708,  0.29682871],
#        [-1.20817959,  0.97471684],
#        [ 0.09073855, -1.32005197]])

# %% [markdown]
# # Cluster Centers and Interpreting the Clusters

# %%
customers_df.groupby("clusterid")[["age","income"]].agg({"age": ["mean", "std"], "income": ["mean", "std"]}).reset_index()
# Out:
#   clusterid        age                  income
#                   mean       std          mean          std
# 0         0  46.419101  2.289620  43053.932584  3613.769632
# 1         1  39.174479  3.626068  18144.791667  6745.241906
# 2         2  31.700435  6.122122  54675.652174  2362.224320

# %%
#cluster0: Customers with mean age of 46 and income of 43k. High age and medium income.
#cluster1: Customers with mean age of 39 and income of 18K. Mid age and low income.
#cluster2: Customers with mean age of 31 and income of 54k. Low age and high income.
